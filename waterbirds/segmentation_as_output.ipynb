# %%
from __future__ import print_function
from __future__ import division
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
from torchvision.datasets.vision import VisionDataset
from torchvision.models.segmentation.deeplabv3 import DeepLabHead
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path
from PIL import Image
from sklearn.metrics import f1_score, roc_auc_score
import time
from tqdm import tqdm
from typing import Any, Callable, Optional
import os
import copy
import csv
import shutil
print("PyTorch Version: ",torch.__version__)
print("Torchvision Version: ",torchvision.__version__)
# Out:
# PyTorch Version:  1.11.0+cu113
# Torchvision Version:  0.12.0+cu113

# %% [markdown]
# ## Download Data

# %%
# Mount to GDrive to get data
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Change this to your own Gdrive path to where the datasets lie in
mount_dir = '/content/drive/My\ Drive/Harvard/2021-22\ Spring\ -\ CS\ 282r/CS\ 282r\ Final\ Project'

# %%
# Seg as output dataset
zipped_dataset = os.path.join(mount_dir, "places_validation_waterbird_95_segout.zip")
# !unzip $zipped_dataset -d '/content/'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Parakeet_Auklet_0062_795958.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Yellow_Breasted_Chat_0039_21654.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Brewer_Sparrow_0060_107391.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Tropical_Kingbird_0122_69687.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Brown_Thrasher_0085_155445.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Field_Sparrow_0034_113364.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/White_Crowned_Sparrow_0010_127651.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Common_Tern_0019_149769.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Cactus_Wren_0016_185582.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Brown_Creeper_0002_24838.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Pine_Grosbeak_0082_38552.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Sage_Thrasher_0025_155661.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Harris_Sparrow_0073_116577.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Ruby_Throated_Hummingbird_0054_57364.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Glaucous_Winged_Gull_0096_45012.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Groove_Billed_Ani_0019_1585.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Geococcyx_0131_104300.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Fish_Crow_0025_25893.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Clay_Colored_Sparrow_0099_110561.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Scott_Oriole_0075_795817.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Chestnut_Sided_Warbler_0094_164152.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Herring_Gull_0114_46956.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Red_Faced_Cormorant_0002_796275.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Common_Raven_0068_101216.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Bay_Breasted_Warbler_0097_159974.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Rusty_Blackbird_0085_6713.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/American_Pipit_0073_99642.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Least_Tern_0037_153637.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Spotted_Catbird_0045_796814.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Yellow_Bellied_Flycatcher_0020_795482.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/White_Necked_Raven_0026_797357.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Horned_Puffin_0052_100977.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Sooty_Albatross_0016_1075.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Gray_Crowned_Rosy_Finch_0006_797284.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Yellow_Bellied_Flycatcher_0037_795500.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Yellow_Breasted_Chat_0090_21931.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Savannah_Sparrow_0011_119459.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Forsters_Tern_0053_152175.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Yellow_Breasted_Chat_0044_22106.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Acadian_Flycatcher_0019_795592.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Bronzed_Cowbird_0017_24019.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Tropical_Kingbird_0064_69889.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Cape_May_Warbler_0005_163197.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Red_Breasted_Merganser_0016_79476.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Winter_Wren_0128_190093.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/White_Breasted_Nuthatch_0055_86075.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Harris_Sparrow_0081_116574.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/American_Three_Toed_Woodpecker_0015_179827.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Slaty_Backed_Gull_0076_796005.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Acadian_Flycatcher_0056_29086.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Prairie_Warbler_0105_172982.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Least_Auklet_0043_795067.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Acadian_Flycatcher_0039_795606.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Hooded_Warbler_0039_164928.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Shiny_Cowbird_0076_24363.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Western_Wood_Pewee_0008_795043.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Field_Sparrow_0066_114109.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Canada_Warbler_0041_162418.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Hooded_Merganser_0036_796771.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Black_Throated_Blue_Warbler_0050_161154.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Pine_Warbler_0037_171649.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Frigatebird_0004_43221.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Summer_Tanager_0006_140137.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Downy_Woodpecker_0073_184430.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Western_Gull_0124_53838.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Chuck_Will_Widow_0012_796956.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Dark_Eyed_Junco_0113_68470.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/White_Breasted_Kingfisher_0022_73459.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Ring_Billed_Gull_0129_51246.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Gadwall_0001_31235.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Pied_Billed_Grebe_0033_35379.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Seaside_Sparrow_0025_796518.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Green_Tailed_Towhee_0069_797441.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Geococcyx_0124_104141.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Least_Tern_0082_154396.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Cerulean_Warbler_0035_163269.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Philadelphia_Vireo_0029_794760.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Yellow_Headed_Blackbird_0082_8577.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Harris_Sparrow_0029_116516.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Brandt_Cormorant_0029_23043.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Western_Gull_0094_55156.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Barn_Swallow_0064_132688.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Rhinoceros_Auklet_0026_797519.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Pigeon_Guillemot_0105_40078.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Cliff_Swallow_0018_132974.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Red_Bellied_Woodpecker_0077_182334.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Ringed_Kingfisher_0021_72848.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Bohemian_Waxwing_0114_177621.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Bewick_Wren_0062_185063.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Black_Tern_0020_144163.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Western_Meadowlark_0040_77823.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Swainson_Warbler_0020_794863.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Cactus_Wren_0058_185903.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Gray_Kingbird_0059_795030.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Evening_Grosbeak_0069_37684.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Orange_Crowned_Warbler_0067_167588.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Ivory_Gull_0020_49978.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Eastern_Towhee_0117_22741.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Elegant_Tern_0068_150526.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Baird_Sparrow_0008_106929.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/White_Eyed_Vireo_0019_159095.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/American_Pipit_0082_99867.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Vermilion_Flycatcher_0061_42397.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Rose_Breasted_Grosbeak_0019_39274.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Groove_Billed_Ani_0012_1784.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Philadelphia_Vireo_0024_156645.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Northern_Waterthrush_0084_177239.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Green_Tailed_Towhee_0060_154820.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Fish_Crow_0044_25964.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Carolina_Wren_0113_186675.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/California_Gull_0053_41011.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Bronzed_Cowbird_0032_796233.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Geococcyx_0009_104372.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Cape_May_Warbler_0031_163012.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Red_Winged_Blackbird_0052_5575.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Brandt_Cormorant_0038_23110.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Black_Capped_Vireo_0018_155868.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Red_Breasted_Merganser_0023_79477.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Common_Tern_0100_149541.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Crested_Auklet_0067_785249.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Florida_Jay_0036_65107.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Indigo_Bunting_0003_13049.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Worm_Eating_Warbler_0097_176010.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Black_Billed_Cuckoo_0074_795286.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Pine_Grosbeak_0019_38845.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Chuck_Will_Widow_0006_796986.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Caspian_Tern_0072_147667.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Great_Crested_Flycatcher_0069_29603.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Downy_Woodpecker_0007_184051.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/White_Crowned_Sparrow_0057_127927.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Northern_Fulmar_0046_43760.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Pine_Grosbeak_0105_38210.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Least_Tern_0038_153087.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Florida_Jay_0047_65088.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Long_Tailed_Jaeger_0068_797093.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Barn_Swallow_0066_130214.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Belted_Kingfisher_0087_70724.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Black_And_White_Warbler_0031_160773.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Harris_Sparrow_0053_116595.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Louisiana_Waterthrush_0091_795246.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Worm_Eating_Warbler_0081_175971.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Northern_Flicker_0123_28381.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Brewer_Sparrow_0032_796702.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Eastern_Towhee_0111_22168.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Herring_Gull_0039_46420.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Yellow_Warbler_0069_176346.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Hooded_Warbler_0013_164627.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Northern_Fulmar_0029_44049.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Marsh_Wren_0097_188214.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Carolina_Wren_0141_186347.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Green_Jay_0036_65660.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Blue_Winged_Warbler_0092_162044.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Western_Gull_0122_40866.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Pine_Warbler_0004_171215.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Scott_Oriole_0012_795837.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Black_Throated_Sparrow_0010_107375.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Rufous_Hummingbird_0113_59444.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Blue_Grosbeak_0020_36967.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Seaside_Sparrow_0050_796508.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Least_Flycatcher_0024_30230.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Ring_Billed_Gull_0127_51485.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Bewick_Wren_0039_184989.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Gadwall_0031_30935.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Groove_Billed_Ani_0033_1494.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Painted_Bunting_0001_16585.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Parakeet_Auklet_0032_795986.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Red_Legged_Kittiwake_0016_795460.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Red_Breasted_Merganser_0002_79447.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Vermilion_Flycatcher_0054_42210.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Downy_Woodpecker_0090_183964.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Orange_Crowned_Warbler_0079_168372.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Hooded_Warbler_0070_164930.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Bay_Breasted_Warbler_0089_797141.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Western_Grebe_0057_36157.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Black_And_White_Warbler_0077_160440.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Brewer_Blackbird_0026_2625.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Red_Legged_Kittiwake_0019_795398.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Yellow_Throated_Vireo_0017_794988.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Glaucous_Winged_Gull_0078_44461.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Glaucous_Winged_Gull_0127_44258.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Downy_Woodpecker_0136_184534.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Baltimore_Oriole_0128_87796.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Dark_Eyed_Junco_0008_68321.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Pigeon_Guillemot_0028_40046.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Laysan_Albatross_0071_792.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Crested_Auklet_0076_785252.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Common_Raven_0037_101096.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Least_Auklet_0038_795132.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Least_Auklet_0042_1874.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Cardinal_0084_17576.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Clay_Colored_Sparrow_0062_110908.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Ring_Billed_Gull_0028_51454.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Brown_Creeper_0118_24500.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/White_Throated_Sparrow_0073_129110.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Northern_Waterthrush_0024_177293.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Sooty_Albatross_0040_796375.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Tennessee_Warbler_0043_175003.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Fish_Crow_0003_25970.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Sooty_Albatross_0077_1080.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Olive_Sided_Flycatcher_0014_30651.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Clark_Nutcracker_0082_85477.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Palm_Warbler_0060_168686.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Ivory_Gull_0074_49698.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Cerulean_Warbler_0033_797176.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/American_Crow_0119_25610.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Rock_Wren_0069_188969.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Horned_Puffin_0055_100882.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Bay_Breasted_Warbler_0099_159753.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Purple_Finch_0102_27308.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Whip_Poor_Will_0050_796415.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Cerulean_Warbler_0020_163353.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Black_Capped_Vireo_0008_797454.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Black_Throated_Sparrow_0020_106971.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Brown_Thrasher_0052_155254.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Grasshopper_Sparrow_0041_116288.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Eared_Grebe_0064_34251.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Pileated_Woodpecker_0032_180347.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Gadwall_0024_30942.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Red_Breasted_Merganser_0046_79330.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Mourning_Warbler_0014_166427.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Northern_Fulmar_0019_43853.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Yellow_Billed_Cuckoo_0050_26424.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Hooded_Oriole_0035_90331.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Yellow_Bellied_Flycatcher_0064_795466.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Red_Breasted_Merganser_0055_79397.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Grasshopper_Sparrow_0050_116301.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Parakeet_Auklet_0038_795935.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Sooty_Albatross_0057_796354.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Henslow_Sparrow_0106_796580.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Dark_Eyed_Junco_0062_68198.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Brown_Creeper_0049_24911.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Grasshopper_Sparrow_0014_116129.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Hooded_Warbler_0008_164641.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Lazuli_Bunting_0095_14919.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Green_Tailed_Towhee_0046_154967.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Song_Sparrow_0042_121314.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Hooded_Merganser_0083_796773.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Slaty_Backed_Gull_0058_796024.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Common_Yellowthroat_0098_190430.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Green_Violetear_0030_795736.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Summer_Tanager_0056_139211.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Red_Eyed_Vireo_0034_157219.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Western_Wood_Pewee_0015_98184.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Rose_Breasted_Grosbeak_0114_39770.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Rufous_Hummingbird_0064_58509.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Song_Sparrow_0125_122435.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Green_Jay_0121_65564.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Common_Raven_0001_101213.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Gray_Catbird_0074_19601.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Orange_Crowned_Warbler_0042_167614.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Herring_Gull_0024_48309.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Black_Billed_Cuckoo_0081_26209.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Grasshopper_Sparrow_0072_115663.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Yellow_Warbler_0097_176538.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Myrtle_Warbler_0037_166690.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Orchard_Oriole_0091_91774.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Horned_Puffin_0016_100993.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/White_Throated_Sparrow_0034_129054.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Cerulean_Warbler_0077_797202.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Black_Tern_0089_144174.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Golden_Winged_Warbler_0030_164462.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Belted_Kingfisher_0016_70495.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Eastern_Towhee_0030_22693.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Pigeon_Guillemot_0077_39885.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Pomarine_Jaeger_0026_61273.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Baird_Sparrow_0028_794557.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Bank_Swallow_0049_129611.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Anna_Hummingbird_0024_55760.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Golden_Winged_Warbler_0054_794847.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Pine_Warbler_0102_171147.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Clay_Colored_Sparrow_0091_110768.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Western_Meadowlark_0125_77850.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Pied_Kingfisher_0106_71404.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Bohemian_Waxwing_0040_177914.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/European_Goldfinch_0078_33170.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Ringed_Kingfisher_0053_72875.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Horned_Grebe_0099_34989.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Downy_Woodpecker_0043_184314.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Red_Legged_Kittiwake_0032_795399.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Nelson_Sharp_Tailed_Sparrow_0055_796937.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Bay_Breasted_Warbler_0072_797114.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Hooded_Oriole_0130_90422.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Great_Crested_Flycatcher_0048_29586.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/European_Goldfinch_0014_794672.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Rose_Breasted_Grosbeak_0020_39152.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Boat_Tailed_Grackle_0113_33490.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Gray_Crowned_Rosy_Finch_0026_27160.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Le_Conte_Sparrow_0084_795189.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Great_Crested_Flycatcher_0027_29532.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Green_Kingfisher_0099_70942.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Chuck_Will_Widow_0054_22782.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Cedar_Waxwing_0031_178929.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/American_Redstart_0022_103701.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Gray_Crowned_Rosy_Finch_0024_27057.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Parakeet_Auklet_0019_795987.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Rose_Breasted_Grosbeak_0068_39094.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Grasshopper_Sparrow_0042_115638.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Chestnut_Sided_Warbler_0081_163854.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Tropical_Kingbird_0103_69311.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Canada_Warbler_0087_162342.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Slaty_Backed_Gull_0020_796012.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Frigatebird_0049_43044.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/American_Redstart_0087_103371.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Fish_Crow_0081_25908.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Fox_Sparrow_0009_114796.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Great_Grey_Shrike_0008_797053.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Tropical_Kingbird_0097_69436.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Blue_Winged_Warbler_0020_161875.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Nighthawk_0022_84183.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Parakeet_Auklet_0007_795932.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Sooty_Albatross_0068_796353.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/House_Sparrow_0128_110971.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Downy_Woodpecker_0014_183975.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Common_Raven_0099_102534.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Florida_Jay_0111_64651.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Common_Yellowthroat_0032_190592.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Sooty_Albatross_0072_796371.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Red_Winged_Blackbird_0025_5342.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/White_Eyed_Vireo_0012_159495.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Swainson_Warbler_0025_794881.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Boat_Tailed_Grackle_0050_33501.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Pied_Billed_Grebe_0070_35472.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Common_Yellowthroat_0069_190400.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Black_And_White_Warbler_0081_110906.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Downy_Woodpecker_0044_184170.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Prairie_Warbler_0053_173290.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Brewer_Blackbird_0131_2289.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Ivory_Gull_0117_49227.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Mangrove_Cuckoo_0042_794628.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/European_Goldfinch_0003_33066.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Whip_Poor_Will_0044_796407.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Summer_Tanager_0058_139427.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Swainson_Warbler_0017_174685.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Olive_Sided_Flycatcher_0017_30704.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Caspian_Tern_0123_145774.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Shiny_Cowbird_0010_24439.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Cedar_Waxwing_0092_179123.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Gray_Kingbird_0006_70268.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Pomarine_Jaeger_0001_795772.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Pileated_Woodpecker_0065_180324.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/White_Crowned_Sparrow_0021_127092.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Tropical_Kingbird_0031_69333.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Summer_Tanager_0088_139473.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Purple_Finch_0082_27639.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Gray_Kingbird_0063_70287.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Scissor_Tailed_Flycatcher_0110_42136.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Magnolia_Warbler_0004_165535.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Yellow_Breasted_Chat_0065_22137.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Prairie_Warbler_0031_172818.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Ruby_Throated_Hummingbird_0095_57990.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/California_Gull_0055_41218.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Mallard_0030_77143.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Hooded_Oriole_0060_90879.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Clark_Nutcracker_0063_84869.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Nashville_Warbler_0092_167457.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Pelagic_Cormorant_0012_23565.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Gray_Crowned_Rosy_Finch_0001_27211.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Palm_Warbler_0117_170073.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Gadwall_0075_30892.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Cardinal_0020_18664.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Mourning_Warbler_0081_166434.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Common_Raven_0121_101744.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Tennessee_Warbler_0019_174786.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Bank_Swallow_0007_129514.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Whip_Poor_Will_0040_100482.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/American_Pipit_0114_100380.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Orchard_Oriole_0075_91847.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Black_Throated_Sparrow_0095_107268.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Whip_Poor_Will_0037_796405.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Herring_Gull_0139_47006.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Cedar_Waxwing_0101_179707.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Belted_Kingfisher_0041_70595.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/American_Goldfinch_0133_32802.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Groove_Billed_Ani_0091_1728.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Fish_Crow_0014_26041.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Cape_Glossy_Starling_0020_129328.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Rock_Wren_0045_189153.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Least_Auklet_0015_795065.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Cedar_Waxwing_0016_178629.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Blue_Headed_Vireo_0039_156397.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Acadian_Flycatcher_0003_29094.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Barn_Swallow_0094_132154.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Myrtle_Warbler_0059_166946.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Nashville_Warbler_0121_167078.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Hooded_Merganser_0032_79032.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Ivory_Gull_0098_49810.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Yellow_Billed_Cuckoo_0002_26715.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Brown_Creeper_0121_24574.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Horned_Grebe_0019_34811.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Myrtle_Warbler_0101_166942.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Mallard_0123_76653.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Yellow_Headed_Blackbird_0070_8583.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Boat_Tailed_Grackle_0117_33576.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Pied_Billed_Grebe_0064_35843.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Green_Kingfisher_0071_71255.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Chuck_Will_Widow_0023_796979.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Prairie_Warbler_0120_173097.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Louisiana_Waterthrush_0004_177455.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Hooded_Oriole_0118_90049.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Nelson_Sharp_Tailed_Sparrow_0013_796942.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Horned_Lark_0013_74374.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Bronzed_Cowbird_0053_24170.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Cactus_Wren_0078_185899.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Gadwall_0017_30979.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Chestnut_Sided_Warbler_0018_164148.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Cardinal_0039_17597.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Bewick_Wren_0054_184902.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Wilson_Warbler_0047_175304.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Field_Sparrow_0074_113504.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/California_Gull_0025_41479.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Horned_Lark_0059_74144.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Loggerhead_Shrike_0127_105742.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Sayornis_0113_98630.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Spotted_Catbird_0005_19411.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Heermann_Gull_0128_45663.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Warbling_Vireo_0076_158500.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Fox_Sparrow_0086_115484.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/House_Wren_0126_187647.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Red_Legged_Kittiwake_0010_73789.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Bank_Swallow_0003_129623.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Blue_Grosbeak_0093_37107.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/White_Necked_Raven_0050_797374.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Herring_Gull_0014_47814.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Eared_Grebe_0058_34174.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/American_Goldfinch_0087_32363.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Painted_Bunting_0060_15224.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Spotted_Catbird_0022_796821.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Western_Wood_Pewee_0020_795054.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Red_Winged_Blackbird_0044_5621.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Yellow_Bellied_Flycatcher_0049_42593.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Scott_Oriole_0008_795814.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/House_Wren_0091_188046.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Kentucky_Warbler_0020_795903.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Black_Throated_Sparrow_0035_107185.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Golden_Winged_Warbler_0092_164465.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Rhinoceros_Auklet_0010_797545.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Blue_Headed_Vireo_0098_156348.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Pileated_Woodpecker_0116_179948.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Cliff_Swallow_0092_132971.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Blue_Grosbeak_0029_37197.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Hooded_Merganser_0061_796723.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Gadwall_0034_31212.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Hooded_Oriole_0075_90788.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Baltimore_Oriole_0092_87435.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Vesper_Sparrow_0019_125558.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/White_Breasted_Kingfisher_0026_73201.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Rock_Wren_0033_189397.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Loggerhead_Shrike_0119_105138.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Warbling_Vireo_0061_158494.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/White_Breasted_Nuthatch_0096_86140.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Clay_Colored_Sparrow_0002_110606.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Yellow_Warbler_0044_176367.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Least_Tern_0088_152941.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Marsh_Wren_0056_188241.png
#   inflating: /content/places_validation_waterbird_95_segout/train/mask/Black_Throated_Blue_Warbler_0017_161220.png
# ...
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/House_Sparrow_0106_111564.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Baltimore_Oriole_0064_89554.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Brown_Pelican_0067_94529.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Tennessee_Warbler_0034_174854.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Ivory_Gull_0099_49218.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Black_Throated_Sparrow_0102_107243.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Rock_Wren_0123_189405.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Great_Crested_Flycatcher_0092_29583.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Cliff_Swallow_0069_133521.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Field_Sparrow_0095_113842.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Least_Tern_0016_153560.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Common_Tern_0030_147825.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Pied_Billed_Grebe_0082_35356.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Grasshopper_Sparrow_0003_115676.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Scott_Oriole_0077_795831.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Common_Raven_0028_102452.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Northern_Fulmar_0041_44013.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Caspian_Tern_0078_146824.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Common_Yellowthroat_0081_190525.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Tropical_Kingbird_0023_69998.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Elegant_Tern_0045_150752.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Crested_Auklet_0061_794904.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Boat_Tailed_Grackle_0085_33384.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Baltimore_Oriole_0038_87083.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Sayornis_0012_98881.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Horned_Lark_0049_74574.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/American_Three_Toed_Woodpecker_0002_179885.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Cliff_Swallow_0088_134188.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Brewer_Sparrow_0022_107440.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Magnolia_Warbler_0054_165965.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Seaside_Sparrow_0027_796512.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Least_Tern_0133_153816.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Nelson_Sharp_Tailed_Sparrow_0079_796934.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Common_Yellowthroat_0072_190402.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Least_Tern_0048_153550.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/White_Necked_Raven_0051_797383.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Frigatebird_0006_43381.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Bobolink_0052_9423.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Elegant_Tern_0061_150524.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Least_Flycatcher_0067_30397.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/House_Sparrow_0137_111219.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Ovenbird_0104_92763.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Red_Winged_Blackbird_0001_3695.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Tree_Swallow_0002_136792.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Cardinal_0083_18042.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Palm_Warbler_0010_169452.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Fish_Crow_0011_25866.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Yellow_Billed_Cuckoo_0026_26794.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Blue_Jay_0054_61656.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Brewer_Blackbird_0064_2290.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Black_Billed_Cuckoo_0088_26217.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Horned_Grebe_0078_34799.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Savannah_Sparrow_0047_119365.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Western_Gull_0051_54320.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Vesper_Sparrow_0044_125470.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Eared_Grebe_0017_34139.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Tree_Sparrow_0074_124408.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Scissor_Tailed_Flycatcher_0003_41849.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Glaucous_Winged_Gull_0032_44594.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Blue_Headed_Vireo_0011_156276.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Red_Headed_Woodpecker_0097_182903.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Red_Legged_Kittiwake_0001_795394.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Red_Headed_Woodpecker_0076_183288.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Groove_Billed_Ani_0090_1567.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Red_Legged_Kittiwake_0031_795442.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Ring_Billed_Gull_0118_51322.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/White_Eyed_Vireo_0009_158830.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Rose_Breasted_Grosbeak_0063_39802.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Green_Jay_0102_65813.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Frigatebird_0082_42989.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Northern_Flicker_0036_28681.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Mockingbird_0019_81296.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Cliff_Swallow_0028_132365.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Horned_Lark_0015_74855.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Swainson_Warbler_0022_794868.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Scarlet_Tanager_0058_137710.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/White_Breasted_Kingfisher_0002_73491.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Painted_Bunting_0086_16540.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Nighthawk_0043_84039.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Ring_Billed_Gull_0098_51410.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Yellow_Breasted_Chat_0032_21823.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Palm_Warbler_0112_169595.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Pied_Kingfisher_0019_72659.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Northern_Waterthrush_0016_177345.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Brown_Thrasher_0081_155256.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/House_Sparrow_0133_112368.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Rusty_Blackbird_0101_6880.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Eastern_Towhee_0027_22372.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Chipping_Sparrow_0042_107791.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Nighthawk_0058_83270.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Yellow_Throated_Vireo_0035_794991.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Gadwall_0042_31411.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Pomarine_Jaeger_0024_61281.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Ruby_Throated_Hummingbird_0079_58075.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/American_Goldfinch_0121_32725.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Golden_Winged_Warbler_0014_164464.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Scott_Oriole_0064_92321.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Scissor_Tailed_Flycatcher_0069_41827.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Rock_Wren_0122_189042.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Canada_Warbler_0077_162437.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Chuck_Will_Widow_0001_796975.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Sage_Thrasher_0069_155544.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Florida_Jay_0088_65147.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Chestnut_Sided_Warbler_0121_164125.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Cape_May_Warbler_0076_163075.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Prairie_Warbler_0040_173056.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Cape_Glossy_Starling_0067_129380.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Western_Wood_Pewee_0059_98262.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Green_Tailed_Towhee_0064_154771.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Gadwall_0077_30929.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Northern_Flicker_0111_28402.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Lincoln_Sparrow_0057_117334.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Pacific_Loon_0013_75530.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Western_Wood_Pewee_0040_795051.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Hooded_Oriole_0125_90382.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Loggerhead_Shrike_0051_105447.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/American_Redstart_0108_103686.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Herring_Gull_0051_46276.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Seaside_Sparrow_0015_796500.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Groove_Billed_Ani_0004_1528.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Slaty_Backed_Gull_0072_53314.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Tennessee_Warbler_0004_174997.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Yellow_Throated_Vireo_0075_795004.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Long_Tailed_Jaeger_0056_797092.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Baird_Sparrow_0046_794588.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Glaucous_Winged_Gull_0034_44625.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Cliff_Swallow_0087_133294.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Red_Bellied_Woodpecker_0010_180772.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Mallard_0114_76924.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Cerulean_Warbler_0071_163201.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Painted_Bunting_0002_16887.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Louisiana_Waterthrush_0080_177379.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Brandt_Cormorant_0087_23126.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Pied_Kingfisher_0074_71830.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Green_Tailed_Towhee_0090_797434.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/House_Sparrow_0082_112478.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Wilson_Warbler_0059_175249.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Swainson_Warbler_0043_794865.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Herring_Gull_0130_46675.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Savannah_Sparrow_0091_120630.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Pacific_Loon_0019_75422.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Eastern_Towhee_0082_22330.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Bewick_Wren_0050_184919.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Horned_Grebe_0088_35023.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Hooded_Merganser_0015_79132.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Bronzed_Cowbird_0092_796215.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Slaty_Backed_Gull_0077_796017.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Tennessee_Warbler_0074_175058.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Wilson_Warbler_0089_175619.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Heermann_Gull_0009_45905.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Gadwall_0005_30924.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Tree_Swallow_0127_135912.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Philadelphia_Vireo_0047_156521.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Evening_Grosbeak_0051_37954.png
#   inflating: /content/places_validation_waterbird_95_segout/val/mask/Groove_Billed_Ani_0036_1604.png

# %% [markdown]
# ## Training
# Inspired by https://towardsdatascience.com/transfer-learning-for-segmentation-using-deeplabv3-in-pytorch-f770863d6a42

# %%
class SegmentationDataset(VisionDataset):
    """A PyTorch dataset for image segmentation task.
    The dataset is compatible with torchvision transforms.
    The transforms passed would be applied to both the Images and Masks.
    """
    def __init__(self,
                 root: str,
                 image_folder: str,
                 mask_folder: str,
                 transforms: Optional[Callable] = None,
                 seed: int = None,
                 fraction: float = None,
                 subset: str = None,
                 image_color_mode: str = "rgb",
                 mask_color_mode: str = "grayscale") -> None:
        """
        Args:
            root (str): Root directory path.
            image_folder (str): Name of the folder that contains the images in the root directory.
            mask_folder (str): Name of the folder that contains the masks in the root directory.
            transforms (Optional[Callable], optional): A function/transform that takes in
            a sample and returns a transformed version.
            E.g, ``transforms.ToTensor`` for images. Defaults to None.
            seed (int, optional): Specify a seed for the train and test split for reproducible results. Defaults to None.
            fraction (float, optional): A float value from 0 to 1 which specifies the validation split fraction. Defaults to None.
            subset (str, optional): 'Train' or 'Test' to select the appropriate set. Defaults to None.
            image_color_mode (str, optional): 'rgb' or 'grayscale'. Defaults to 'rgb'.
            mask_color_mode (str, optional): 'rgb' or 'grayscale'. Defaults to 'grayscale'.
        Raises:
            OSError: If image folder doesn't exist in root.
            OSError: If mask folder doesn't exist in root.
            ValueError: If subset is not either 'Train' or 'Test'
            ValueError: If image_color_mode and mask_color_mode are either 'rgb' or 'grayscale'
        """
        super().__init__(root, transforms)
        image_folder_path = Path(self.root) / image_folder
        mask_folder_path = Path(self.root) / mask_folder
        if not image_folder_path.exists():
            raise OSError(f"{image_folder_path} does not exist.")
        if not mask_folder_path.exists():
            raise OSError(f"{mask_folder_path} does not exist.")

        if image_color_mode not in ["rgb", "grayscale"]:
            raise ValueError(
                f"{image_color_mode} is an invalid choice. Please enter from rgb grayscale."
            )
        if mask_color_mode not in ["rgb", "grayscale"]:
            raise ValueError(
                f"{mask_color_mode} is an invalid choice. Please enter from rgb grayscale."
            )

        self.image_color_mode = image_color_mode
        self.mask_color_mode = mask_color_mode

        if not fraction:
            self.image_names = sorted(image_folder_path.glob("*"))
            self.mask_names = sorted(mask_folder_path.glob("*"))
        else:
            # if subset not in ["Train", "Test"]:
            #     raise (ValueError(
            #         f"{subset} is not a valid input. Acceptable values are Train and Test."
            #     ))
            self.fraction = fraction
            self.image_list = np.array(sorted(image_folder_path.glob("*")))
            self.mask_list = np.array(sorted(mask_folder_path.glob("*")))
            if seed:
                np.random.seed(seed)
                indices = np.arange(len(self.image_list))
                np.random.shuffle(indices)
                self.image_list = self.image_list[indices]
                self.mask_list = self.mask_list[indices]
            if subset == "train":
                self.image_names = self.image_list[:int(
                    np.ceil(len(self.image_list) * (1 - self.fraction)))]
                self.mask_names = self.mask_list[:int(
                    np.ceil(len(self.mask_list) * (1 - self.fraction)))]
            else:
                self.image_names = self.image_list[
                    int(np.ceil(len(self.image_list) * (1 - self.fraction))):]
                self.mask_names = self.mask_list[
                    int(np.ceil(len(self.mask_list) * (1 - self.fraction))):]

    def __len__(self) -> int:
        return len(self.image_names)

    def __getitem__(self, index: int) -> Any:
        image_path = self.image_names[index]
        mask_path = self.mask_names[index]
        with open(image_path, "rb") as image_file, open(mask_path,
                                                        "rb") as mask_file:
            image = Image.open(image_file)
            if self.image_color_mode == "rgb":
                image = image.convert("RGB")
            elif self.image_color_mode == "grayscale":
                image = image.convert("L")
            mask = Image.open(mask_file)
            if self.mask_color_mode == "rgb":
                mask = mask.convert("RGB")
            elif self.mask_color_mode == "grayscale":
                mask = mask.convert("L")
            sample = {"image": image, "mask": mask}
            if self.transforms:
                sample["image"] = self.transforms(sample["image"])
                sample["mask"] = self.transforms(sample["mask"])
            return sample

# %%
# Create train, val, test dataloaders from separate folders.
def get_dataloader_sep_folder(data_dir: str,
                              image_folder: str = 'image',
                              mask_folder: str = 'mask',
                              batch_size: int = 4):
    """ 
    Args:
        data_dir (str): The data directory or root.
        image_folder (str, optional): Image folder name. Defaults to 'image'.
        mask_folder (str, optional): Mask folder name. Defaults to 'mask'.
        batch_size (int, optional): Batch size of the dataloader. Defaults to 4.
    Returns:
        dataloaders: Returns dataloaders dictionary containing the
        Train and Test dataloaders.
    """
    data_transforms = transforms.Compose([
                                          transforms.RandomResizedCrop(224),
                                          transforms.ToTensor(),
                                        ])

    image_datasets = {
        x: SegmentationDataset(root=Path(data_dir) / x,
                               transforms=data_transforms,
                               image_folder=image_folder,
                               mask_folder=mask_folder)
        for x in ['train', 'val', 'test']
    }

    dataloaders = {
        x: DataLoader(image_datasets[x],
                      batch_size=batch_size,
                      shuffle=True,
                      num_workers=8)
        for x in ['train', 'val', 'test']
    }
    return dataloaders

# %%
def createDeepLabv3(outputchannels=1):
    """DeepLabv3 class with custom head
    Args:
        outputchannels (int, optional): The number of output channels
        in your dataset masks. Defaults to 1.
    Returns:
        model: Returns the DeepLabv3 model with the ResNet101 backbone.
    """
    model = models.segmentation.deeplabv3_resnet101(pretrained=True,
                                                    progress=True)
    model.classifier = DeepLabHead(2048, outputchannels)
    # Set the model in training mode
    model.train()
    return model

# %%
def train_model(model, criterion, dataloaders, optimizer, metrics, bpath,
                num_epochs):
    since = time.time()
    best_model_wts = copy.deepcopy(model.state_dict())
    best_loss = 1e10
    # Use gpu if available
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    model.to(device)
    # Initialize the log file for training and testing loss and metrics
    fieldnames = ['epoch', 'train_loss', 'val_loss', 'test_loss'] + \
        [f'train_{m}' for m in metrics.keys()] + \
        [f'val_{m}' for m in metrics.keys()] + \
        [f'test_{m}' for m in metrics.keys()]
    with open(os.path.join(bpath, 'log.csv'), 'w', newline='') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()

    for epoch in range(1, num_epochs + 1):
        print('Epoch {}/{}'.format(epoch, num_epochs))
        print('-' * 10)
        # Each epoch has a training and validation phase
        # Initialize batch summary
        batchsummary = {a: [0] for a in fieldnames}

        for phase in ['train', 'val', 'test']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()  # Set model to evaluate mode

            # Iterate over data.
            for sample in tqdm(iter(dataloaders[phase])):
                inputs = sample['image'].to(device)
                masks = sample['mask'].to(device)
                # zero the parameter gradients
                optimizer.zero_grad()

                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    loss = criterion(outputs['out'], masks)
                    y_pred = outputs['out'].data.cpu().numpy().ravel()
                    y_true = masks.data.cpu().numpy().ravel()
                    for name, metric in metrics.items():
                        if name == 'f1_score':
                            # Use a classification threshold of 0.1
                            batchsummary[f'{phase}_{name}'].append(
                                metric(y_true > 0, y_pred > 0.1))
                        else:
                            batchsummary[f'{phase}_{name}'].append(
                                metric(y_true.astype('uint8'), y_pred))

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()
            batchsummary['epoch'] = epoch
            epoch_loss = loss
            batchsummary[f'{phase}_loss'] = epoch_loss.item()
            print('{} Loss: {:.4f}'.format(phase, loss))
        for field in fieldnames[3:]:
            batchsummary[field] = np.mean(batchsummary[field])
        print(batchsummary)
        with open(os.path.join(bpath, 'log.csv'), 'a', newline='') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
            writer.writerow(batchsummary)
            # deep copy the model
            if phase == 'test' and loss < best_loss:
                best_loss = loss
                best_model_wts = copy.deepcopy(model.state_dict())

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Lowest Loss: {:4f}'.format(best_loss))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %% [markdown]
# ## Run

# %%
model = createDeepLabv3()
model.train()
# Out:
# Downloading: "https://download.pytorch.org/models/deeplabv3_resnet101_coco-586e9e4e.pth" to /root/.cache/torch/hub/checkpoints/deeplabv3_resnet101_coco-586e9e4e.pth
#   0%|          | 0.00/233M [00:00<?, ?B/s]
# DeepLabV3(
#   (backbone): IntermediateLayerGetter(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (6): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (7): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (8): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (9): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (10): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (11): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (12): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (13): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (14): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (15): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (16): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (17): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (18): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (19): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (20): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (21): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (22): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#   )
#   (classifier): DeepLabHead(
#     (0): ASPP(
#       (convs): ModuleList(
#         (0): Sequential(
#           (0): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (1): ASPPConv(
#           (0): Conv2d(2048, 256, kernel_size=(3, 3), stride=(1, 1), padding=(12, 12), dilation=(12, 12), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (2): ASPPConv(
#           (0): Conv2d(2048, 256, kernel_size=(3, 3), stride=(1, 1), padding=(24, 24), dilation=(24, 24), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (3): ASPPConv(
#           (0): Conv2d(2048, 256, kernel_size=(3, 3), stride=(1, 1), padding=(36, 36), dilation=(36, 36), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (4): ASPPPooling(
#           (0): AdaptiveAvgPool2d(output_size=1)
#           (1): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (3): ReLU()
#         )
#       )
#       (project): Sequential(
#         (0): Conv2d(1280, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout(p=0.5, inplace=False)
#       )
#     )
#     (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU()
#     (4): Conv2d(256, 1, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (aux_classifier): FCNHead(
#     (0): Conv2d(1024, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.1, inplace=False)
#     (4): Conv2d(256, 21, kernel_size=(1, 1), stride=(1, 1))
#   )
# )

# %%
data_directory = "places_validation_waterbird_95_segout"
# Create the experiment directory if not present
exp_directory = Path("exp_directory")
if not exp_directory.exists():
    exp_directory.mkdir()

# %%
# Specify the loss function
criterion = torch.nn.MSELoss(reduction='mean')
# Specify the optimizer with a lower learning rate
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

# Specify the evaluation metrics
metrics = {'f1_score': f1_score, 'auroc': roc_auc_score}

# %%
# %xmode Plain
# %pdb on

# Create the dataloader
dataldr = get_dataloader_sep_folder(data_directory)

train_model(model,
            criterion,
            dataldr,
            optimizer,
            bpath=exp_directory,
            metrics=metrics,
            num_epochs=15)

# Save the trained model
torch.save(model, exp_directory / 'weights.pt')
# Out:
# Exception reporting mode: Plain
# Automatic pdb calling has been turned ON
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch 1/15
# ----------
# 100%|██████████| 1199/1199 [11:53<00:00,  1.68it/s]
# train Loss: 0.2257
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 100%|██████████| 300/300 [01:10<00:00,  4.27it/s]
# val Loss: 0.1331
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 100%|██████████| 1449/1449 [05:34<00:00,  4.33it/s]
# test Loss: 0.1280
# {'epoch': 1, 'train_loss': 0.22567357122898102, 'val_loss': 0.13310422003269196, 'test_loss': 0.12797023355960846, 'train_f1_score': 0.4602405058357744, 'train_auroc': 0.6626254863394394, 'val_f1_score': 0.4353909127819525, 'val_auroc': 0.6803330994959457, 'test_f1_score': 0.4406325533931175, 'test_auroc': 0.6853658027284494}
# Epoch 2/15
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 100%|██████████| 1199/1199 [11:59<00:00,  1.67it/s]
# train Loss: 0.0832
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 100%|██████████| 300/300 [01:10<00:00,  4.28it/s]
# val Loss: 0.1450
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 100%|██████████| 1449/1449 [05:35<00:00,  4.33it/s]
# test Loss: 0.1421
# {'epoch': 2, 'train_loss': 0.08321881294250488, 'val_loss': 0.14502303302288055, 'test_loss': 0.1421322375535965, 'train_f1_score': 0.4633446859010843, 'train_auroc': 0.6881287121517888, 'val_f1_score': 0.4564899976614857, 'val_auroc': 0.6873241825746729, 'test_f1_score': 0.46528580350650484, 'test_auroc': 0.6917784674974482}
# Epoch 3/15
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 100%|██████████| 1199/1199 [11:58<00:00,  1.67it/s]
# train Loss: 0.1487
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 100%|██████████| 300/300 [01:09<00:00,  4.29it/s]
# val Loss: 0.1514
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 100%|██████████| 1449/1449 [05:34<00:00,  4.33it/s]
# test Loss: 0.2775
# {'epoch': 3, 'train_loss': 0.14868895709514618, 'val_loss': 0.15140332281589508, 'test_loss': 0.27747395634651184, 'train_f1_score': 0.46562393324416607, 'train_auroc': 0.6956770913057001, 'val_f1_score': 0.44296041587791296, 'val_auroc': 0.6349778327353449, 'test_f1_score': 0.4394347828089028, 'test_auroc': 0.618841901887392}
# Epoch 4/15
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 100%|██████████| 1199/1199 [11:57<00:00,  1.67it/s]
# train Loss: 0.0791
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 100%|██████████| 300/300 [01:09<00:00,  4.29it/s]
# val Loss: 0.1789
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 100%|██████████| 1449/1449 [05:35<00:00,  4.32it/s]
# test Loss: 0.1323
# {'epoch': 4, 'train_loss': 0.07909736037254333, 'val_loss': 0.17890024185180664, 'test_loss': 0.1322832852602005, 'train_f1_score': 0.46540234720111073, 'train_auroc': 0.7019354112205084, 'val_f1_score': 0.4412508310920208, 'val_auroc': 0.7093869346231787, 'test_f1_score': 0.4441594186669788, 'test_auroc': 0.6962362959681319}
# Epoch 5/15
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 100%|██████████| 1199/1199 [11:58<00:00,  1.67it/s]
# train Loss: 0.1792
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 100%|██████████| 300/300 [01:11<00:00,  4.19it/s]
# val Loss: 0.1198
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 100%|██████████| 1449/1449 [05:35<00:00,  4.31it/s]
# test Loss: 0.1866
# {'epoch': 5, 'train_loss': 0.17921729385852814, 'val_loss': 0.11976911127567291, 'test_loss': 0.186604842543602, 'train_f1_score': 0.46819495603352873, 'train_auroc': 0.6977685151875236, 'val_f1_score': 0.4730599830166441, 'val_auroc': 0.6997720184916469, 'test_f1_score': 0.47734310851376177, 'test_auroc': 0.697814177169654}
# Epoch 6/15
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 100%|██████████| 1199/1199 [11:57<00:00,  1.67it/s]
# train Loss: 0.2052
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 100%|██████████| 300/300 [01:10<00:00,  4.26it/s]
# val Loss: 0.1382
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 100%|██████████| 1449/1449 [05:36<00:00,  4.31it/s]
# test Loss: 0.1500
# {'epoch': 6, 'train_loss': 0.20520812273025513, 'val_loss': 0.13823223114013672, 'test_loss': 0.14997971057891846, 'train_f1_score': 0.4709731155766434, 'train_auroc': 0.706795823773338, 'val_f1_score': 0.4732401777957125, 'val_auroc': 0.7030191587549046, 'test_f1_score': 0.4694754744635644, 'test_auroc': 0.6981639390769627}
# Epoch 7/15
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 100%|██████████| 1199/1199 [11:58<00:00,  1.67it/s]
# train Loss: 0.1160
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 100%|██████████| 300/300 [01:10<00:00,  4.24it/s]
# val Loss: 0.1643
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 100%|██████████| 1449/1449 [05:36<00:00,  4.30it/s]
# test Loss: 0.2135
# {'epoch': 7, 'train_loss': 0.1159554049372673, 'val_loss': 0.1642545908689499, 'test_loss': 0.21354003250598907, 'train_f1_score': 0.4682374423426521, 'train_auroc': 0.7076123709379883, 'val_f1_score': 0.45065834198089477, 'val_auroc': 0.6960035595703763, 'test_f1_score': 0.4490630430916209, 'test_auroc': 0.6994408927499342}
# Epoch 8/15
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
#  29%|██▊       | 343/1199 [03:25<08:32,  1.67it/s]
# Traceback (most recent call last):
#
#   File "<ipython-input-12-32df58004f7e>", line 13, in <module>
#     num_epochs=15)
#
#   File "<ipython-input-8-f673482e1608>", line 48, in train_model
#     metric(y_true.astype('uint8'), y_pred))
#
#   File "/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py", line 572, in roc_auc_score
#     sample_weight=sample_weight,
#
#   File "/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_base.py", line 75, in _average_binary_score
#     return binary_metric(y_true, y_score, sample_weight=sample_weight)
#
#   File "/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py", line 338, in _binary_roc_auc_score
#     "Only one class present in y_true. ROC AUC score "
#
# ValueError: Only one class present in y_true. ROC AUC score is not defined in that case.
# > /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py(338)_binary_roc_auc_score()
#     336     if len(np.unique(y_true)) != 2:
#     337         raise ValueError(
# --> 338             "Only one class present in y_true. ROC AUC score "
#     339             "is not defined in that case."
#     340         )
#
# ipdb> c
# PYDEV DEBUGGER WARNING:
# sys.settrace() should not be used when the debugger is being used.
# This may cause the debugger to stop working correctly.
# If this is needed, please check:
# http://pydev.blogspot.com/2007/06/why-cant-pydev-debugger-work-with.html
# to see how to restore the debug tracing back correctly.
# Call Location:
#   File "/usr/lib/python3.7/bdb.py", line 343, in set_continue
#     sys.settrace(None)
